# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.model_selection import train_test_split
import joblib
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 9
#       7 from sklearn.preprocessing import PowerTransformer
#       8 from sklearn.preprocessing import StandardScaler
# ----> 9 import tensorflow as tf
#      10 from tensorflow.keras.callbacks import EarlyStopping
#      11 from sklearn.compose import ColumnTransformer
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\python\pywrap_tensorflow.py:88
#      86     sys.setdlopenflags(_default_dlopen_flags)
#      87 except ImportError:
# ---> 88   raise ImportError(
#      89       f'{traceback.format_exc()}'
#      90       f'\n\nFailed to load the native TensorFlow runtime.\n'
#      91       f'See https://www.tensorflow.org/install/errors '
#      92       f'for some common causes and solutions.\n'
#      93       f'If you need help, create an issue '
#      94       f'at https://github.com/tensorflow/tensorflow/issues '
#      95       f'and include the entire stack trace above this error message.')
#      97 # pylint: enable=wildcard-import,g-import-not-at-top,unused-import,line-too-long
#
# ImportError: Traceback (most recent call last):
#   File "C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorflow\python\pywrap_tensorflow.py", line 73, in <module>
#     from tensorflow.python._pywrap_tensorflow_internal import *
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
#
# Failed to load the native TensorFlow runtime.
# See https://www.tensorflow.org/install/errors for some common causes and solutions.
# If you need help, create an issue at https://github.com/tensorflow/tensorflow/issues and include the entire stack trace above this error message.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data_path = "../Datasets/fin_ds.csv" 
df = pd.read_csv(data_path)

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
df['trip_duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60

# %%
df = df[df['trip_duration'] > 0]

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'pickup_longitude',
#        'pickup_latitude', 'RateCodeID', 'store_and_fwd_flag',
#        'dropoff_longitude', 'dropoff_latitude', 'payment_type', 'fare_amount',
#        'extra', 'mta_tax', 'tip_amount', 'tolls_amount',
#        'improvement_surcharge', 'total_amount', 'RatecodeID', 'date_ordinal',
#        'SNOW_pred', 'TAVG_pred', 'PRCP_pred', 'trip_duration'],
#       dtype='object')

# %%
df['ordinal_datetime'] = df['tpep_pickup_datetime'].apply(lambda x: x.toordinal())

# %%
features = ['trip_distance', 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'ordinal_datetime', 'SNOW_pred', 'TAVG_pred', 'PRCP_pred']
target = 'trip_duration'

X = df[features]
y = df[target]

# %%
skew = X.skew()

# %%
cols = []
for i,v in enumerate(skew):
    if -1<v<1:
        pass
    else:
        cols.append(X.columns[i])

# %%
cols
# Out:
# ['trip_distance',
#  'pickup_longitude',
#  'pickup_latitude',
#  'dropoff_longitude',
#  'dropoff_latitude',
#  'ordinal_datetime']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('pt', PowerTransformer(method='yeo-johnson'), cols[:-1])
    ],
    remainder='passthrough'
)

# %%
pipe = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler())
])

# %%
X_processed = pipe.fit_transform(X)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_processed.shape[1],)),
    # tf.keras.layers.Dense(256,activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1)  
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse')

# %%
history = model.fit(X_processed, y,
                    validation_split=0.2,
                    epochs=250,
                    batch_size=32,
                    verbose=1)
# Out:
# Epoch 1/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1081.8394 - val_loss: 134.1349
# Epoch 2/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1884.9956 - val_loss: 50.0827
# Epoch 3/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 586.6311 - val_loss: 69.3591
# Epoch 4/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1701.0925 - val_loss: 44.8429
# Epoch 5/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1050.5221 - val_loss: 73.0820
# Epoch 6/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1502.4534 - val_loss: 62.3733
# Epoch 7/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1869.7634 - val_loss: 55.4725
# Epoch 8/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 889.8628 - val_loss: 70.8047
# Epoch 9/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 647.5685 - val_loss: 119.3106
# Epoch 10/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1872.4000 - val_loss: 62.5039
# Epoch 11/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 225.5121 - val_loss: 122.9142
# Epoch 12/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 347.5948 - val_loss: 106.1156
# Epoch 13/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3730.8064 - val_loss: 85.4250
# Epoch 14/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1155.1854 - val_loss: 90.7078
# Epoch 15/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3034.1204 - val_loss: 81.4347
# Epoch 16/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 116.1332 - val_loss: 93.3279
# Epoch 17/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 435.8670 - val_loss: 126.8897
# Epoch 18/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 898.7988 - val_loss: 93.1400
# Epoch 19/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1220.3357 - val_loss: 76.9814
# Epoch 20/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1859.6553 - val_loss: 69.0465
# Epoch 21/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1414.5724 - val_loss: 67.6203
# Epoch 22/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 987.2537 - val_loss: 68.2130
# Epoch 23/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133.6248 - val_loss: 75.8358
# Epoch 24/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3280.2834 - val_loss: 60.3073
# Epoch 25/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1966.7249 - val_loss: 62.5988
# Epoch 26/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5491.2275 - val_loss: 61.6671
# Epoch 27/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2213.9487 - val_loss: 61.4696
# Epoch 28/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 518.4078 - val_loss: 96.3027
# Epoch 29/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1485.8784 - val_loss: 62.9022
# Epoch 30/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3271.5493 - val_loss: 59.3522
# Epoch 31/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 324.0137 - val_loss: 93.3421
# Epoch 32/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 838.2166 - val_loss: 75.3840
# Epoch 33/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1836.9777 - val_loss: 59.1802
# Epoch 34/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2352.1997 - val_loss: 57.7704
# Epoch 35/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1032.9944 - val_loss: 71.0031
# Epoch 36/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 382.2697 - val_loss: 96.0400
# Epoch 37/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 188.5278 - val_loss: 74.7149
# Epoch 38/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1474.1895 - val_loss: 57.7977
# Epoch 39/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1946.4296 - val_loss: 57.3950
# Epoch 40/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1141.3344 - val_loss: 60.2771
# Epoch 41/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 925.2869 - val_loss: 71.7369
# Epoch 42/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4233.0776 - val_loss: 55.9865
# Epoch 43/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 973.7379 - val_loss: 66.8002
# Epoch 44/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 82.1811 - val_loss: 56.6161
# Epoch 45/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 886.8024 - val_loss: 69.1333
# Epoch 46/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2335.3118 - val_loss: 58.7596
# Epoch 47/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1258.4132 - val_loss: 62.0365
# Epoch 48/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2939.5210 - val_loss: 56.6223
# Epoch 49/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 782.7139 - val_loss: 71.0844
# Epoch 50/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1632.0956 - val_loss: 59.6485
# Epoch 51/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 702.1879 - val_loss: 72.9189
# Epoch 52/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1196.3961 - val_loss: 60.1923
# Epoch 53/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 621.0217 - val_loss: 74.1664
# Epoch 54/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1259.9427 - val_loss: 59.1263
# Epoch 55/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 971.8060 - val_loss: 66.4276
# Epoch 56/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1466.7256 - val_loss: 58.9826
# Epoch 57/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1720.0457 - val_loss: 54.8272
# Epoch 58/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3229.6592 - val_loss: 55.7176
# Epoch 59/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 779.7516 - val_loss: 70.4965
# Epoch 60/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5363.9526 - val_loss: 55.5780
# Epoch 61/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1072.9719 - val_loss: 60.6501
# Epoch 62/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1317.8895 - val_loss: 60.6131
# Epoch 63/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4191.1587 - val_loss: 51.2278
# Epoch 64/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2683.5347 - val_loss: 55.3788
# Epoch 65/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 265.2847 - val_loss: 67.5872
# Epoch 66/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 239.3884 - val_loss: 76.9516
# Epoch 67/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1701.8369 - val_loss: 53.4125
# Epoch 68/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1816.3027 - val_loss: 56.5166
# Epoch 69/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1063.4041 - val_loss: 61.7014
# Epoch 70/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 346.7630 - val_loss: 85.3801
# Epoch 71/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1900.9545 - val_loss: 52.3089
# Epoch 72/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2668.9109 - val_loss: 54.5532
# Epoch 73/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1615.1876 - val_loss: 55.7853
# Epoch 74/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2022.2670 - val_loss: 54.8802
# Epoch 75/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2152.7437 - val_loss: 52.9473
# Epoch 76/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1376.6876 - val_loss: 56.7933
# Epoch 77/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 346.9287 - val_loss: 83.8123
# Epoch 78/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 667.3337 - val_loss: 67.3090
# Epoch 79/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1079.4006 - val_loss: 62.8572
# Epoch 80/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 301.8713 - val_loss: 66.0538
# Epoch 81/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 196.6444 - val_loss: 66.6237
# Epoch 82/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1069.9856 - val_loss: 58.3026
# Epoch 83/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3554.6304 - val_loss: 53.5149
# Epoch 84/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 161.8479 - val_loss: 54.0385
# Epoch 85/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1774.9805 - val_loss: 52.8841
# Epoch 86/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2645.0286 - val_loss: 52.3372
# Epoch 87/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 611.7362 - val_loss: 74.5053
# Epoch 88/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 296.9536 - val_loss: 68.0619
# Epoch 89/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 184.1766 - val_loss: 67.7903
# Epoch 90/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 271.4561 - val_loss: 75.4348
# Epoch 91/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1675.1025 - val_loss: 54.2250
# Epoch 92/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2869.9138 - val_loss: 49.0895
# Epoch 93/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2444.7073 - val_loss: 50.1284
# Epoch 94/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2005.3588 - val_loss: 53.8608
# Epoch 95/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 504.6523 - val_loss: 76.9804
# Epoch 96/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3510.4128 - val_loss: 51.7833
# Epoch 97/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 417.6299 - val_loss: 83.5429
# Epoch 98/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2108.1755 - val_loss: 49.6295
# Epoch 99/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2118.2068 - val_loss: 62.2654
# Epoch 100/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 503.3576 - val_loss: 76.1299
# Epoch 101/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 448.5992 - val_loss: 84.8979
# Epoch 102/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 770.0416 - val_loss: 70.8973
# Epoch 103/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2387.5229 - val_loss: 50.3392
# Epoch 104/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 467.6322 - val_loss: 81.1239
# Epoch 105/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 296.2692 - val_loss: 78.2254
# Epoch 106/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 537.0333 - val_loss: 76.1875
# Epoch 107/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 355.5090 - val_loss: 86.9824
# Epoch 108/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1650.3020 - val_loss: 53.0551
# Epoch 109/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 463.1639 - val_loss: 76.0835
# Epoch 110/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 374.0113 - val_loss: 89.5638
# Epoch 111/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1097.9746 - val_loss: 62.5303
# Epoch 112/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3068.5679 - val_loss: 49.0294
# Epoch 113/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 506.2141 - val_loss: 83.6420
# Epoch 114/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 643.7917 - val_loss: 86.1076
# Epoch 115/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 290.2284 - val_loss: 65.3656
# Epoch 116/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1265.8285 - val_loss: 63.1881
# Epoch 117/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2100.8916 - val_loss: 54.6077
# Epoch 118/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1299.3639 - val_loss: 74.8031
# Epoch 119/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1403.1306 - val_loss: 56.0844
# Epoch 120/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 846.8803 - val_loss: 84.4264
# Epoch 121/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 250.8260 - val_loss: 61.2318
# Epoch 122/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1076.0804 - val_loss: 66.9275
# Epoch 123/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 604.8690 - val_loss: 89.4340
# Epoch 124/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1026.2195 - val_loss: 74.6048
# Epoch 125/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1387.1217 - val_loss: 63.3787
# Epoch 126/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 230.0333 - val_loss: 63.9007
# Epoch 127/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 384.4129 - val_loss: 95.2508
# Epoch 128/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 718.8620 - val_loss: 83.4650
# Epoch 129/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2028.3870 - val_loss: 52.2934
# Epoch 130/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 280.3858 - val_loss: 82.1567
# Epoch 131/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2156.5190 - val_loss: 50.9414
# Epoch 132/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1274.5059 - val_loss: 75.5997
# Epoch 133/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 396.8492 - val_loss: 76.8420
# Epoch 134/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 187.6607 - val_loss: 77.8825
# Epoch 135/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 332.1143 - val_loss: 79.0877
# Epoch 136/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2152.3362 - val_loss: 55.0057
# Epoch 137/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 333.2223 - val_loss: 89.2184
# Epoch 138/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 331.1248 - val_loss: 107.5642
# Epoch 139/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 227.4655 - val_loss: 78.4290
# Epoch 140/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 902.5894 - val_loss: 65.6585
# Epoch 141/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 
250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 174.9628 - val_loss: 102.5611
# Epoch 200/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 458.2976 - val_loss: 143.0984
# Epoch 201/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 486.8460 - val_loss: 183.1504
# Epoch 202/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 128.7359 - val_loss: 75.1496
# Epoch 203/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1474.9695 - val_loss: 74.0829
# Epoch 204/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 470.7663 - val_loss: 221.2643
# Epoch 205/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 814.5527 - val_loss: 210.1896
# Epoch 206/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 475.4331 - val_loss: 218.7166
# Epoch 207/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 521.1676 - val_loss: 248.6764
# Epoch 208/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1624.7831 - val_loss: 84.5925
# Epoch 209/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 369.8066 - val_loss: 236.8090
# Epoch 210/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 200.3661 - val_loss: 155.1214
# Epoch 211/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 925.5205 - val_loss: 166.9809
# Epoch 212/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 909.5657 - val_loss: 176.7430
# Epoch 213/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1695.9457 - val_loss: 85.6705
# Epoch 214/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 235.5149 - val_loss: 208.8006
# Epoch 215/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2265.5291 - val_loss: 63.6217
# Epoch 216/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 248.6312 - val_loss: 199.2269
# Epoch 217/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1453.0868 - val_loss: 129.3627
# Epoch 218/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 742.3123 - val_loss: 235.4170
# Epoch 219/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1360.5316 - val_loss: 97.3211
# Epoch 220/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 333.1248 - val_loss: 229.4778
# Epoch 221/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1662.7803 - val_loss: 125.8684
# Epoch 222/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2109.1174 - val_loss: 122.4696
# Epoch 223/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 145.7014 - val_loss: 120.3344
# Epoch 224/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 335.3880 - val_loss: 293.9601
# Epoch 225/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 717.6390 - val_loss: 188.2355
# Epoch 226/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 664.5844 - val_loss: 303.0752
# Epoch 227/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 537.4675 - val_loss: 260.0190
# Epoch 228/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 171.7845 - val_loss: 174.4646
# Epoch 229/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 659.6293 - val_loss: 229.0371
# Epoch 230/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 391.9004 - val_loss: 380.6505
# Epoch 231/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 366.3819 - val_loss: 327.9395
# Epoch 232/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 340.6897 - val_loss: 331.3086
# Epoch 233/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 322.7197 - val_loss: 404.5476
# Epoch 234/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1108.1360 - val_loss: 149.8803
# Epoch 235/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 341.1791 - val_loss: 467.0100
# Epoch 236/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 255.7283 - val_loss: 158.9927
# Epoch 237/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 497.3803 - val_loss: 447.8941
# Epoch 238/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 511.4840 - val_loss: 346.5788
# Epoch 239/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1692.0872 - val_loss: 204.8379
# Epoch 240/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 137.2589 - val_loss: 186.7726
# Epoch 241/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1608.4011 - val_loss: 164.1668
# Epoch 242/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 261.3234 - val_loss: 341.9964
# Epoch 243/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 653.3607 - val_loss: 451.7773
# Epoch 244/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 805.6993 - val_loss: 308.4611
# Epoch 245/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 628.3322 - val_loss: 436.5298
# Epoch 246/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 212.3997 - val_loss: 352.8143
# Epoch 247/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 724.4896 - val_loss: 304.6711
# Epoch 248/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1101.0807 - val_loss: 217.5786
# Epoch 249/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 985.9410 - val_loss: 225.6732
# Epoch 250/250
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 588.5513 - val_loss: 581.6534

# %%
model_filename = '../models/trip_duration_model.h5'
model.save(model_filename)
print(f"Trained model saved as {model_filename}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Trained model saved as trip_duration_model.h5

# %%
joblib.dump(pipe, '../preprocessors/preprocessing_pipeline.pkl')

print(f"Saved pt as preprocessing_pipeline.pkl")
# Out:
# Saved pt as preprocessing_pipeline.pkl
